# %% [markdown]
# # 🔗 How to Connect to 12 - DataShip Client Success Reporting GitHub Repo (Mac & Windows)
#
# This guide walks you through setting up a system where you can:
#
# - Use **Google Colab** to write and run Python code
# - Store your project in the 12 - DataShip Client Success Reporting **Google Drive**
# - **Version control your files using GitHub**, with commits made from your local computer

# %% [markdown]
# #### ✅  Prerequisites
# - A GitHub account
# - A Google account
# - Google Drive for Desktop installed on your computer
# - Git installed on your computer

# %% [markdown]
# ### 🖥️ Step-by-Step: Mac Setup.

# %% [markdown]
# 1. Install Google Drive for Desktop
#
# Download from: https://www.google.com/drive/download/
# - Sign in with the same Google account you use for Colab.
# - Choose to stream or mirror files (either works).
#
# 2. Access a Shared Folder '12 - DataShip Client Success Reporting' on Google Drive
#
# If the project folder '12 - DataShip Client Success Reporting' was shared with you
# - Go to https://drive.google.com/drive/shared-with-me
# - Right-click the folder → Add shortcut to Drive
# - Choose a location inside My Drive
#
# 💡 This is crucial — only folders inside "My Drive" will sync to your computer.
#
# 3. Find the Synced Folder Path
#
#     Once the shortcut is created, Drive will sync it to:
#     ```~/Library/CloudStorage/GoogleDrive-your_email@gmail.com/My Drive/```
#
#     Check if the '12 - DataShip Client Success Reporting' folder exists via terminal:
#     ```ls ~/Library/CloudStorage```
#
# 4. IMPORTANT: Avoid Double-Folder Issue When Cloning
#
#     If the folder 12 - DataShip Client Success Reporting already exists in your Drive, do not clone the GitHub repo into it as a subfolder.
#
#     Instead, do one of the following:
#
#     ✅ Option A: Treat the existing folder as your repo folder
#
#         ```
#         cd ~/Library/CloudStorage/GoogleDrive-your_email@gmail.com/My\ Drive/12\ -\ DataShip\ Client\ Success\ Reporting
#
#         git init
#         git remote add origin https://github.com/abualfaki/ClientSuccess-Dashboard.git
#         # To get the latest code from GitHub
#         git pull origin main # Optional if you want to sync with the latest Github Version
#         ```
#
#         ✅ Best Practice:
#         If possible, always git clone directly from GitHub instead of downloading from Google Drive.
#
#     ✅ Option B: Clone directly into the folder (only if it's empty or you're setting it up fresh)
#
#         ```
#         cd ~/Library/CloudStorage/GoogleDrive-your_email@gmail.com/My\ Drive/
#         git clone https://github.com/abualfaki/ClientSuccess-Dashboard.git "12 - DataShip Client Success Reporting"
#         ```
#
#         ❌ Avoid running git clone inside the folder — that would create a nested subfolder like 12 - DataShip Client Success Reporting/ClientSuccess-Dashboard, which can lead to confusion.
#
# 5. Commit & Push From Your Local Terminal
#
#     After making changes (e.g. in Colab):
#
#         ```
#         git status
#         git add .
#         git commit -m "Update from Colab"
#         git push origin main
#         ```

# %% [markdown]
# ### 📓 Notes From Experience
#
# - Google Docs (.gdoc, .gsheet) are shortcuts, not real files — Git won’t track them.
#
# - Add .gitkeep files to empty folders so Git tracks the structure.
#
# - If your folder isn’t syncing to your local machine, make sure it’s in "My Drive", not just "Shared with me".
#
# - Use .gitignore to avoid tracking:
#     - .DS_Store (Mac)
#     - Colab checkpoints: *.ipynb_checkpoints
#
# - To confirm you're in the right place, create a file from Colab and check if it appears on your computer:
#
# ```with open('/content/drive/MyDrive/12 - DataShip Client Success Reporting/TEST_SYNC.txt', 'w') as f:
# f.write("It works!")```

# %% [markdown]
# ### 🚫 Protecting the main Branch (Best Practice for Teams)
#
# When working in teams to connect GitHub to Google Drive, it’s important to protect the `` branch so it isn’t accidentally overwritten by someone else’s push.
#
# #### ✅ Option 1: Use Feature Branches
#
#     Ask collaborators to create a branch for their work:
#
#     ```
#     git checkout -b feature-yourname
#     # make changes
#     git add .
#     git commit -m "Your updates"
#     git push origin feature-yourname
#     ```
#
#     Then, go to GitHub and create a Pull Request to merge into main.
#
# #### ✅ Option 2: Enable Branch Protection in GitHub
#
#     To prevent direct pushes to main:
#
#     Go to your GitHub repo → Settings → Branches
#
#     Click Add rule under Branch protection rules
#
#     Type main as the branch name
#
#     Check:
#
#     ✅ Require pull request before merging
#
#     ✅ Require approvals (optional)
#
#     This adds a safety net and promotes clean collaboration.

# %% [markdown]
# ## 🗂️ Visual Git Flow Diagram
#
#   Google Colab ↔ Google Drive
#          ↓            ↓
#      Local Git ←→ GitHub Repo
#
# Work in Colab and save to Google Drive
#
# Drive syncs to your local machine
#
# Local Git manages version control and syncs with GitHub

# %% [markdown]
# ## 🛠️ Troubleshooting Guide
#
# 🔹 Folder not showing in your local Drive?
# - ➡️ Go to Shared with Me and add a shortcut to My Drive.
#
# 🔹 .gdoc or .gsheet files not appearing in Git?
# - ➡️ These are shortcuts, not real files. Export them as .docx or .xlsx to track them.
#
# 🔹 Accidentally cloned inside the folder?
# - ➡️ Delete the nested folder and re-clone using Option B or initialize using Option A.
#
# 🔹 Not seeing file changes in Git?
# - ➡️ Run git status to confirm you're in the correct repo directory and check .gitignore for exclusions.

# %% [markdown]
# ## ✅ You're Set!
#
# You now have a robust workflow where:
#
# - Google Drive is your shared and synced storage
# - Colab is your cloud-based coding environment
# - GitHub tracks your progress
# - Your local terminal gives you full version control
# - And your main branch is protected for team collaboration
